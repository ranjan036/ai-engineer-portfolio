# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.dataset_analyzer import DataSetAnalyzer

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

analyzer = DataSetAnalyzer(url)

# %% [markdown]
# Analyse and observe the data# Clean the data

# %%
#analyzer.run_all()

# %% [markdown]
# Lets build first calssification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# Load the data

# %%
df = analyzer.load_data()
#print(df)

# %% [markdown]
# Train the model

# %%
analyzer.prepare_data("species")

model = KNeighborsClassifier()
analyzer.train_model(model)
# Out:
# Data prepared successfully
# Model is trained successfully

# %% [markdown]
# Evaluation of the model

# %%
acc = analyzer.evaluate_model()
print(acc)
# Out:
# 1.0

# %% [markdown]
# Make predictions

# %%
input_data = [5.1, 3.5, 1.4, 0.2]
result  = analyzer.predict(input_data)
print(result)
# Out:
# setosa
